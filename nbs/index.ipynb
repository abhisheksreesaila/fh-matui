# %%
#| hide
from fh_matui.core import *

# %% [markdown]
# # fh-matui
#
# > material-ui for fasthtml

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install fh_matui in Development mode

# %% [markdown]
# ```sh
# # make sure fh_matui package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to fh_matui
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/abhishek sreesaila/fh-matui.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c abhishek sreesaila fh_matui
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install fh_matui
# ```
#
#
# [repo]: https://github.com/abhishek sreesaila/fh-matui
# [docs]: https://abhishek sreesaila.github.io/fh-matui/
# [pypi]: https://pypi.org/project/fh-matui/
# [conda]: https://anaconda.org/abhishek sreesaila/fh-matui

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/abhishek sreesaila/fh-matui
# [docs]: https://abhishek sreesaila.github.io/fh-matui/
# [pypi]: https://pypi.org/project/fh-matui/
# [conda]: https://anaconda.org/abhishek sreesaila/fh-matui

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
