# %%
from fh_matui.foundations import *

# %%
#| hide

# Test cases for stringify edge cases
assert stringify('abc') == 'abc'
assert stringify(('abc','def')) == 'abc def'
assert 'uk-input ' + stringify(()) == 'uk-input '
assert 'uk-input ' + stringify("") == 'uk-input '

print("✓ Additional stringify edge case tests passed")
# Out:
# ✓ Additional stringify edge case tests passed

# %%
#| hide

assert str(VEnum.__members__) or True  # VEnum is defined
assert stringify('abc') == 'abc'
assert stringify(('abc','def')) == 'abc def'
assert stringify([]) == ""
assert stringify(["a", "b"]) == "a b"
assert 'uk-input ' + stringify(()) == 'uk-input '
assert 'uk-input ' + stringify("") == 'uk-input '
assert normalize_tokens(None) == []
assert normalize_tokens("class1 class2") == ["class1", "class2"]
assert dedupe_preserve_order(["a", "b", "a", "c"]) == ["a", "b", "c"]

print("✅ All tests passed!")
# Out:
# ✅ All tests passed!
